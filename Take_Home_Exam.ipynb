# %% [markdown]
# # Take Home Exam

# %% [markdown]
# ## Instructions:
# * Make sure that you run all code cells that are included in this notebook.
# * I will deduct points in **half-point steps** in the following cases:
#     * Your code does not work.
#     * You are not answering the question (Read carefully).
#     * Your code is slow or inefficient.
#     * You do not explain why you are doing what you are doing.
#     * Clean **unnecessary** elements before submission.
#     * **Check the rubric on Camino for this assignment!**
#
# **The deadline is Saturday, February 10, 2018, 11:59PM**.
#
# **I am not available on Saturday and have only limited access to my email. If you have questions or issues, make sure you adress them on Friday. **

# %% [markdown]
# ## Overview

# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.4f}'.format

# %%
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
cd = pd.read_csv('complications.csv', dtype=str).rename(columns=lambda x: x.strip())

# %% [markdown]
# This dataset contains complications in U.S. hospitals. Each observation represents the number of complications and the 30-day death rate for a specific complication in a specific hospital.

# %% [markdown]
# The columns are as follows:

# %%
cd.columns
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'ZIP Code',
#        'County Name', 'Phone Number', 'Year', 'Measure ID', 'Measure Name',
#        'Denominator', 'Score', 'Lower Estimate', 'Higher Estimate'],
#       dtype='object')

# %% [markdown]
# | Column Name | Description|
# |-------------|------------|
# |Provider ID | Unique ID of the hospital |
# |Hospital Name| Name of the hospital|
# |Address| Address of the hospital|
# |City| Name of the city the hospital is in |
# |ZIP Code | Postal code of the hospital|
# |County Name | Name of the county the hospital is in|
# |Phone Number | Phone number of the hospital |
# |Year | The year in which the complications were recorded|
# |Measure ID | Code for the complication |
# |Measure Name | Name of the complication|
# |Denominator| Number of underlying medical procedures|
# |Score | Estimate for number of serious complications |
# |Lower Estimate | Lower boundary of score|
# |Higher Estimate | Upper boundary of score|

# %% [markdown]
# A quick overview of the dataset:

# %%
cd.describe()
# Out:
#        Denominator       Score  Lower Estimate  Higher Estimate       ratio
# count  272788.0000 272788.0000     272788.0000      272788.0000 272788.0000
# mean      956.3320     11.6061          9.4429          16.8768      0.1037
# std      2425.9633     14.4392         14.1699          26.8144      0.1513
# min        25.0000      0.0300          0.0000           0.0600      0.0000
# 25%        94.0000      3.0000          1.4100           4.9400      0.0086
# 50%       222.0000     10.8000          7.9000          14.3000      0.0435
# 75%       584.0000     15.6000         12.5000          19.5000      0.1270
# max     75866.0000    183.4200        172.8050         244.7000      0.9997

# %% [markdown]
# A sample of the dataset:

# %%
cd.sample(5, random_state=1234).head()
# Out:
#        Provider ID                                 Hospital Name  \
# 22678       050222              SHARP CHULA VISTA MEDICAL CENTER
# 22088       050191                        ST MARY MEDICAL CENTER
# 111295      201309                        MAYO REGIONAL HOSPITAL
# 44865       100012                         LEE MEMORIAL HOSPITAL
# 208974      390194  BLUE MOUNTAIN HOSPITAL-GNADEN HUETTEN CAMPUS
#
#                          Address            City ZIP Code  County Name  \
# 22678   751 MEDICAL CENTER COURT     CHULA VISTA    91911    SAN DIEGO
# 22088            1050 LINDEN AVE      LONG BEACH    90813  LOS ANGELES
# 111295      897 WEST MAIN STREET  DOVER FOXCROFT    04426  PISCATAQUIS
# 44865         2776 CLEVELAND AVE      FORT MYERS    33901          LEE
# 208974     211 NORTH 12TH STREET       LEHIGHTON    18235       CARBON
#
#        Phone Number       Year           Measure ID  \
# 22678    6195025800 2016-01-01           MORT_30_PN
# 22088    5624919000 2012-01-01  PSI_14_POSTOP_DEHIS
# 111295   2075644251 2014-01-01          MORT_30_STK
# 44865    2393321111 2012-01-01           MORT_30_PN
# 208974   6073771300 2016-01-01          MORT_30_STK
#
#                                              Measure Name  Denominator  \
# 22678                Pneumonia (PN) 30-Day Mortality Rate     474.0000
# 22088   A wound that splits open  after surgery on the...     102.0000
# 111295                     Death rate for stroke patients      43.0000
# 44865                Pneumonia (PN) 30-Day Mortality Rate     971.0000
# 208974                     Death rate for stroke patients      72.0000
#
#          Score  Lower Estimate  Higher Estimate  ratio
# 22678  14.3000         12.1000          16.8000 0.0302
# 22088   1.7800          0.0000           3.6400 0.0175
# 111295 14.1000         10.2000          18.9000 0.3279
# 44865  10.6000          8.9000          12.5000 0.0109
# 208974 15.7000         11.7000          20.8000 0.2181

# %% [markdown]
# # Transform relevant columns

# %% [markdown]
# All columns in the dataset are of type `str` (to preserve the ZIP code information). For **five** columns, str is the wrong type. Change the columns and explain why you changed which column.

# %%
# Based on common sense and the column description, column 'Year' should be in the format of datetime, weakness is it's in the format of year-month-day
# And Column 'Denominator','Score','Higher Estimate' are either numbers or scores, which can be better displayed in numerical format for further calculation
# Also, I tried to clean the data before we transfer

cd['Denominator'].replace(to_replace = r'[^0-9.]+', value='', regex=True, inplace=True)
cd['Denominator'] = pd.to_numeric(cd['Denominator'])

cd['Score'].replace(to_replace = r'[^0-9.]+', value='', regex=True, inplace=True)
cd['Score'] = pd.to_numeric(cd['Score'])

cd['Lower Estimate'].replace(to_replace = r'[^0-9.]+', value='', regex=True, inplace=True)
cd['Lower Estimate'] = pd.to_numeric(cd['Lower Estimate'])

cd['Higher Estimate'].replace(to_replace = r'[^0-9.]+', value='', regex=True, inplace=True)
cd['Higher Estimate'] = pd.to_numeric(cd['Higher Estimate'])

cd['Year'] = pd.to_datetime(cd['Year'],exact=True, format='%Y')

# %% [markdown]
# # Create a ratio between the score and the denominator

# %% [markdown]
# Create a new column in the dataset that contains the ratio value.

# %%
cd['ratio'] = cd['Score']/cd['Denominator']
cd
# Out:
#        Provider ID                                      Hospital Name  \
# 0           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 2           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 3           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 4           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 5           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 6           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 7           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 8           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 9           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 10          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 11          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 12          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 13          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 14          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 15          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 16          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 17          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 18          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 19          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 20          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 21          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 22          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 23          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 24          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 25          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 26          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 27          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 28          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 29          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# ...            ...                                                ...
# 272758      670098                           RESOLUTE HEALTH HOSPITAL
# 272759      670098                           RESOLUTE HEALTH HOSPITAL
# 272760      670103                              MEDICAL CITY ALLIANCE
# 272761      670103                              MEDICAL CITY ALLIANCE
# 272762      670103                              MEDICAL CITY ALLIANCE
# 272763      670103                         MEDICAL CENTER OF ALLIANCE
# 272764      670103                         MEDICAL CENTER OF ALLIANCE
# 272765      670103                              MEDICAL CITY ALLIANCE
# 272766      670103                         MEDICAL CENTER OF ALLIANCE
# 272767      670103                              MEDICAL CITY ALLIANCE
# 272768      670103                         MEDICAL CENTER OF ALLIANCE
# 272769      670103                         MEDICAL CENTER OF ALLIANCE
# 272770      670103                              MEDICAL CITY ALLIANCE
# 272771      670106                            PEARLAND MEDICAL CENTER
# 272772      670106                            PEARLAND MEDICAL CENTER
# 272773      670106                            PEARLAND MEDICAL CENTER
# 272774      670106                            PEARLAND MEDICAL CENTER
# 272775      670106                            PEARLAND MEDICAL CENTER
# 272776      670106                            PEARLAND MEDICAL CENTER
# 272777      670106                            PEARLAND MEDICAL CENTER
# 272778      670106                            PEARLAND MEDICAL CENTER
# 272779      670106                            PEARLAND MEDICAL CENTER
# 272780      670106                            PEARLAND MEDICAL CENTER
# 272781      670106                            PEARLAND MEDICAL CENTER
# 272782      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 272783      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 272784      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 272785      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 272786      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 272787      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
#
#                            Address           City ZIP Code County Name  \
# 0           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 1           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 2           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 3           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 4           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 5           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 6           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 7           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 8           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 9           1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 10          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 11          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 12          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 13          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 14          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 15          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 16          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 17          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 18          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 19          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 20          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 21          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 22          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 23          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 24          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 25          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 26          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 27          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 28          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# 29          1108 ROSS CLARK CIRCLE         DOTHAN    36301     HOUSTON
# ...                            ...            ...      ...         ...
# 272758         555 CREEKSIDE XING,  NEW BRAUNFELS    78130       COMAL
# 272759         555 CREEKSIDE XING,  NEW BRAUNFELS    78130       COMAL
# 272760  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272761  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272762  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272763  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272764  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272765  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272766  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272767  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272768  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272769  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272770  3101 NORTH TARRANT PARKWAY     FORT WORTH    76177     TARRANT
# 272771  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272772  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272773  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272774  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272775  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272776  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272777  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272778  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272779  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272780  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272781  11100 SHADOW CREEK PARKWAY       PEARLAND    77584    BRAZORIA
# 272782            810 W HIGHWAY 71   MARBLE FALLS    78654      BURNET
# 272783            810 W HIGHWAY 71   MARBLE FALLS    78654      BURNET
# 272784            810 W HIGHWAY 71   MARBLE FALLS    78654      BURNET
# 272785            810 W HIGHWAY 71   MARBLE FALLS    78654      BURNET
# 272786            810 W HIGHWAY 71   MARBLE FALLS    78654      BURNET
# 272787            810 W HIGHWAY 71   MARBLE FALLS    78654      BURNET
#
#        Phone Number       Year      Measure ID  \
# 0        3347938701 2011-01-01   COMP_HIP_KNEE
# 1        3347938701 2012-01-01   COMP_HIP_KNEE
# 2        3347938701 2013-01-01   COMP_HIP_KNEE
# 3        3347938701 2014-01-01   COMP_HIP_KNEE
# 4        3347938701 2015-01-01   COMP_HIP_KNEE
# 5        3347938701 2016-01-01   COMP_HIP_KNEE
# 6        3347938701 2011-01-01     MORT_30_AMI
# 7        3347938701 2012-01-01     MORT_30_AMI
# 8        3347938701 2013-01-01     MORT_30_AMI
# 9        3347938701 2014-01-01     MORT_30_AMI
# 10       3347938701 2015-01-01     MORT_30_AMI
# 11       3347938701 2016-01-01     MORT_30_AMI
# 12       3347938701 2014-01-01    MORT_30_CABG
# 13       3347938701 2015-01-01    MORT_30_CABG
# 14       3347938701 2016-01-01    MORT_30_CABG
# 15       3347938701 2011-01-01    MORT_30_COPD
# 16       3347938701 2012-01-01    MORT_30_COPD
# 17       3347938701 2013-01-01    MORT_30_COPD
# 18       3347938701 2014-01-01    MORT_30_COPD
# 19       3347938701 2015-01-01    MORT_30_COPD
# 20       3347938701 2016-01-01    MORT_30_COPD
# 21       3347938701 2011-01-01      MORT_30_HF
# 22       3347938701 2012-01-01      MORT_30_HF
# 23       3347938701 2013-01-01      MORT_30_HF
# 24       3347938701 2014-01-01      MORT_30_HF
# 25       3347938701 2015-01-01      MORT_30_HF
# 26       3347938701 2016-01-01      MORT_30_HF
# 27       3347938701 2011-01-01      MORT_30_PN
# 28       3347938701 2012-01-01      MORT_30_PN
# 29       3347938701 2013-01-01      MORT_30_PN
# ...             ...        ...             ...
# 272758   4698396778 2015-01-01  PSI_8_POST_HIP
# 272759   4698396778 2015-01-01  PSI_9_POST_HEM
# 272760   8176391100 2014-01-01      MORT_30_PN
# 272761   8176391100 2015-01-01      MORT_30_PN
# 272762   8176391100 2016-01-01      MORT_30_PN
# 272763   8176391100 2014-01-01  PSI_15_ACC_LAC
# 272764   8176391100 2015-01-01  PSI_15_ACC_LAC
# 272765   8176391100 2015-01-01     PSI_3_ULCER
# 272766   8176391100 2014-01-01   PSI_6_IAT_PTX
# 272767   8176391100 2015-01-01   PSI_6_IAT_PTX
# 272768   8176391100 2014-01-01     PSI_7_CVCBI
# 272769   8176391100 2015-01-01     PSI_7_CVCBI
# 272770   8176391100 2015-01-01  PSI_8_POST_HIP
# 272771   7137707000 2014-01-01      MORT_30_HF
# 272772   7137707000 2015-01-01      MORT_30_HF
# 272773   7137707000 2016-01-01      MORT_30_HF
# 272774   7137707000 2014-01-01  PSI_15_ACC_LAC
# 272775   7137707000 2015-01-01  PSI_15_ACC_LAC
# 272776   7137707000 2015-01-01     PSI_3_ULCER
# 272777   7137707000 2014-01-01   PSI_6_IAT_PTX
# 272778   7137707000 2015-01-01   PSI_6_IAT_PTX
# 272779   7137707000 2014-01-01     PSI_7_CVCBI
# 272780   7137707000 2015-01-01     PSI_7_CVCBI
# 272781   7137707000 2015-01-01  PSI_8_POST_HIP
# 272782   8302017308 2014-01-01    MORT_30_COPD
# 272783   8302017308 2015-01-01    MORT_30_COPD
# 272784   8302017308 2016-01-01    MORT_30_COPD
# 272785   8302017308 2014-01-01      MORT_30_PN
# 272786   8302017308 2015-01-01      MORT_30_PN
# 272787   8302017308 2016-01-01      MORT_30_PN
#
#                                              Measure Name  Denominator  \
# 0       Rate of complications for hip/knee replacement...     356.0000
# 1       Rate of complications for hip/knee replacement...     347.0000
# 2       Rate of complications for hip/knee replacement...     341.6667
# 3       Rate of complications for hip/knee replacement...     335.3333
# 4       Rate of complications for hip/knee replacement...     334.0000
# 5       Rate of complications for hip/knee replacement...     337.0000
# 6       Acute Myocardial Infarction (AMI) 30-Day Morta...     668.0000
# 7       Acute Myocardial Infarction (AMI) 30-Day Morta...     668.0000
# 8       Acute Myocardial Infarction (AMI) 30-Day Morta...     668.0000
# 9       Acute Myocardial Infarction (AMI) 30-Day Morta...     744.0000
# 10      Acute Myocardial Infarction (AMI) 30-Day Morta...     744.0000
# 11      Acute Myocardial Infarction (AMI) 30-Day Morta...     744.0000
# 12                                    Death rate for CABG     280.0000
# 13                                    Death rate for CABG     280.0000
# 14                                    Death rate for CABG     280.0000
# 15      Death rate for chronic obstructive pulmonary d...     574.0000
# 16      Death rate for chronic obstructive pulmonary d...     574.0000
# 17      Death rate for chronic obstructive pulmonary d...     574.0000
# 18      Death rate for chronic obstructive pulmonary d...     522.0000
# 19      Death rate for chronic obstructive pulmonary d...     522.0000
# 20      Death rate for chronic obstructive pulmonary d...     522.0000
# 21               Heart failure (HF) 30-Day Mortality Rate     746.0000
# 22               Heart failure (HF) 30-Day Mortality Rate     746.0000
# 23               Heart failure (HF) 30-Day Mortality Rate     746.0000
# 24               Heart failure (HF) 30-Day Mortality Rate     858.0000
# 25               Heart failure (HF) 30-Day Mortality Rate     858.0000
# 26               Heart failure (HF) 30-Day Mortality Rate     858.0000
# 27                   Pneumonia (PN) 30-Day Mortality Rate     350.0000
# 28                   Pneumonia (PN) 30-Day Mortality Rate     350.0000
# 29                   Pneumonia (PN) 30-Day Mortality Rate     350.0000
# ...                                                   ...          ...
# 272758               Broken hip from a fall after surgery     422.5000
# 272759          Perioperative Hemorrhage or Hematoma Rate     180.0000
# 272760               Pneumonia (PN) 30-Day Mortality Rate      26.0000
# 272761               Pneumonia (PN) 30-Day Mortality Rate      26.0000
# 272762               Pneumonia (PN) 30-Day Mortality Rate      26.0000
# 272763   Accidental cuts and tears from medical treatment      49.0000
# 272764   Accidental cuts and tears from medical treatment      49.0000
# 272765                                     Pressure sores      51.0000
# 272766            Collapsed lung due to medical treatment      47.0000
# 272767            Collapsed lung due to medical treatment      76.5000
# 272768            Infections from a large venous catheter      32.0000
# 272769            Infections from a large venous catheter      32.0000
# 272770               Broken hip from a fall after surgery      92.0000
# 272771           Heart failure (HF) 30-Day Mortality Rate      25.0000
# 272772           Heart failure (HF) 30-Day Mortality Rate      25.0000
# 272773           Heart failure (HF) 30-Day Mortality Rate      25.0000
# 272774   Accidental cuts and tears from medical treatment      59.0000
# 272775   Accidental cuts and tears from medical treatment      59.0000
# 272776                                     Pressure sores      86.0000
# 272777            Collapsed lung due to medical treatment      58.0000
# 272778            Collapsed lung due to medical treatment     100.0000
# 272779            Infections from a large venous catheter      36.0000
# 272780            Infections from a large venous catheter      36.0000
# 272781               Broken hip from a fall after surgery     121.0000
# 272782  Death rate for chronic obstructive pulmonary d...      26.0000
# 272783  Death rate for chronic obstructive pulmonary d...      26.0000
# 272784  Death rate for chronic obstructive pulmonary d...      26.0000
# 272785               Pneumonia (PN) 30-Day Mortality Rate      60.0000
# 272786               Pneumonia (PN) 30-Day Mortality Rate      60.0000
# 272787               Pneumonia (PN) 30-Day Mortality Rate      60.0000
#
#          Score  Lower Estimate  Higher Estimate  ratio
# 0       3.7000          2.5000           5.5000 0.0104
# 1       3.8000          2.5500           5.6000 0.0110
# 2       3.8000          2.5667           5.5667 0.0111
# 3       3.9667          2.7000           5.7333 0.0118
# 4       4.0000          2.7500           5.7500 0.0120
# 5       4.2000          2.9000           6.0000 0.0125
# 6      13.0000         10.9000          15.6000 0.0195
# 7      13.0000         10.9000          15.6000 0.0195
# 8      13.0000         10.9000          15.6000 0.0195
# 9      13.4000         11.4000          15.8000 0.0180
# 10     13.4000         11.4000          15.8000 0.0180
# 11     13.4000         11.4000          15.8000 0.0180
# 12      3.5000          2.1000           5.8000 0.0125
# 13      3.5000          2.1000           5.8000 0.0125
# 14      3.5000          2.1000           5.8000 0.0125
# 15      8.8000          7.0000          11.2000 0.0153
# 16      8.8000          7.0000          11.2000 0.0153
# 17      8.8000          7.0000          11.2000 0.0153
# 18      9.7000          7.6000          12.3000 0.0186
# 19      9.7000          7.6000          12.3000 0.0186
# 20      9.7000          7.6000          12.3000 0.0186
# 21     12.4000         10.5000          14.8000 0.0166
# 22     12.4000         10.5000          14.8000 0.0166
# 23     12.4000         10.5000          14.8000 0.0166
# 24     11.4000          9.5000          13.6000 0.0133
# 25     11.4000          9.5000          13.6000 0.0133
# 26     11.4000          9.5000          13.6000 0.0133
# 27     11.4000          8.9000          14.5000 0.0326
# 28     11.4000          8.9000          14.5000 0.0326
# 29     11.4000          8.9000          14.5000 0.0326
# ...        ...             ...              ...    ...
# 272758  0.0800          0.0400           0.1200 0.0002
# 272759  4.8700          2.4000           7.3300 0.0271
# 272760 14.6000         10.1000          20.9000 0.5615
# 272761 14.6000         10.1000          20.9000 0.5615
# 272762 14.6000         10.1000          20.9000 0.5615
# 272763  1.4100          0.0000           2.9000 0.0288
# 272764  1.4100          0.0000           2.9000 0.0288
# 272765  0.2500          0.0000           1.0100 0.0049
# 272766  0.4100          0.0800           0.7400 0.0087
# 272767  0.4050          0.0850           0.7200 0.0053
# 272768  0.1700          0.0000           0.5000 0.0053
# 272769  0.1700          0.0000           0.5000 0.0053
# 272770  0.1000          0.0200           0.1800 0.0011
# 272771 11.5000          7.7000          16.5000 0.4600
# 272772 11.5000          7.7000          16.5000 0.4600
# 272773 11.5000          7.7000          16.5000 0.4600
# 272774  1.4100          0.0000           2.8900 0.0239
# 272775  1.4100          0.0000           2.8900 0.0239
# 272776  0.2500          0.0000           1.0000 0.0029
# 272777  0.4100          0.0800           0.7300 0.0071
# 272778  0.4050          0.0850           0.7150 0.0041
# 272779  0.1700          0.0000           0.5000 0.0047
# 272780  0.1700          0.0000           0.5000 0.0047
# 272781  0.1000          0.0200           0.1800 0.0008
# 272782  8.0000          5.3000          11.9000 0.3077
# 272783  8.0000          5.3000          11.9000 0.3077
# 272784  8.0000          5.3000          11.9000 0.3077
# 272785 14.8000         10.9000          19.9000 0.2467
# 272786 14.8000         10.9000          19.9000 0.2467
# 272787 14.8000         10.9000          19.9000 0.2467
#
# [272788 rows x 15 columns]

# %% [markdown]
# # Create an overview of the ratio for deathly complications

# %% [markdown]
# 0. **Be careful when you identify 'deathly' complications and make sure that you catch all of them.**
# 1. Create the overview (Make sure that the overview is understandable to everyone.)
# 2. Choose an appropriate measure to aggregate the data. **Ignore that the data is for multiple years**.
# 2. Sort with the highest ratio on top.

# %%
# Check Measure Name to figure out ones that related to death
cd['Measure Name'].unique()

# %%
# Select the rows i need for new dataframe
d1 = cd['Measure Name'] == 'Acute Myocardial Infarction (AMI) 30-Day Mortality Rate'
d2 = cd['Measure Name'] == 'Death rate for CABG'
d3 = cd['Measure Name'] == 'Death rate for chronic obstructive pulmonary disease (COPD) patients'
d4 = cd['Measure Name'] == 'Heart failure (HF) 30-Day Mortality Rate'
d5 = cd['Measure Name'] == 'Pneumonia (PN) 30-Day Mortality Rate'
d6 = cd['Measure Name'] == 'Death rate for stroke patients'

# Combine them into new dataframe
deathly = cd[d1 | d2 | d3 | d4 | d5 | d6]

# Group by measure names and sort their ratios in a descending way, here i use mean because compared with sum or others, mean can best represent the data's whole situation
deathly.groupby(by='Measure Name')['ratio'].mean().sort_values(ascending=False)
# Out:
# Measure Name
# Death rate for stroke patients                                         0.1848
# Acute Myocardial Infarction (AMI) 30-Day Mortality Rate                0.1599
# Heart failure (HF) 30-Day Mortality Rate                               0.1217
# Pneumonia (PN) 30-Day Mortality Rate                                   0.1159
# Death rate for chronic obstructive pulmonary disease (COPD) patients   0.0833
# Death rate for CABG                                                    0.0415
# Name: ratio, dtype: float64

# %% [markdown]
# # Identify the five safest hospitals

# %% [markdown]
# Return a **list** with the hospitals that have, on average, the lowest rate of deadly complications. **Be careful when you identify 'deathly' complications.** (Again, ignore that the dataset covers multiple years).

# %%
# Set up a new empty list for storage
good_hospital=[]

# Group by hospital names and then find the five smallest number based on ratio's mean value 
list=deathly.groupby(by='Hospital Name')['ratio'].mean().nsmallest(5)

# Append value into the empty list
good_hospital.append(list)
good_hospital
# Out:
# [Hospital Name
#  FLORIDA HOSPITAL                        0.0070
#  NEW YORK-PRESBYTERIAN HOSPITAL          0.0079
#  CHRISTIANA CARE HEALTH SERVICES, INC.   0.0081
#  SOUTHCOAST HOSPITAL GROUP, INC          0.0084
#  BEAUMONT HOSPITAL, ROYAL OAK            0.0092
#  Name: ratio, dtype: float64]

# %% [markdown]
# # Augment the datset with information about the state

# %% [markdown]
# Read the file `geo-data.csv` into an object `zip_codes`. **Make sure that you read all columns as string.** ([Link](https://github.com/scpike/us-state-county-zip))

# %%
zip_codes = pd.read_csv('geo-data.csv', dtype=str).rename(columns=lambda x: x.strip())

# %% [markdown]
# This file contains information about the relationship of zip codes, counties, and U.S. states.

# %%
zip_codes.columns
# Out:
# Index(['state_fips', 'state', 'state_abbr', 'zipcode', 'county', 'city'], dtype='object')

# %% [markdown]
# | Column Name | Description|
# |-------------|------------|
# |state_fips | FIPS code for the state |
# |state| Name of the state|
# |state_abbr| Abbreviation of the state|
# |zipcode | Postal code|
# |county | County name|
# |city | City name  |

# %% [markdown]
# 1. Combine the dataset on complications with the dateset on zip codes.
# 2. Explain why you chose the column that used to combine the datasets.
# 3. **Do not worry, not all states will be matched.**

# %%
# Rename deathly's column to match the to-merge object column
deathly = deathly.rename(columns={'ZIP Code': 'zipcode'})

# Join matching rows from zip_codes to deathly, because deathly has already been worked before with more specific data, and it overlapes many columns of zipcodes one, on the other hand, zip_codes are prone to be raw data. Also, merge on condition should be zipcode, because it's unique in US 
M= pd.merge(deathly, zip_codes, how='left', on='zipcode')
M
# Out:
#        Provider ID                                      Hospital Name  \
# 0           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 2           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 3           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 4           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 5           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 6           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 7           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 8           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 9           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 10          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 11          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 12          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 13          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 14          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 15          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 16          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 17          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 18          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 19          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 20          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 21          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 22          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 23          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 24          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 25          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 26          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 27          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 28          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 29          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# ...            ...                                                ...
# 103602      670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 103603      670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 103604      670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 103605      670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 103606      670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 103607      670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 103608      670098                           RESOLUTE HEALTH HOSPITAL
# 103609      670098                           RESOLUTE HEALTH HOSPITAL
# 103610      670098                           RESOLUTE HEALTH HOSPITAL
# 103611      670098                           RESOLUTE HEALTH HOSPITAL
# 103612      670098                           RESOLUTE HEALTH HOSPITAL
# 103613      670098                           RESOLUTE HEALTH HOSPITAL
# 103614      670098                           RESOLUTE HEALTH HOSPITAL
# 103615      670098                           RESOLUTE HEALTH HOSPITAL
# 103616      670098                           RESOLUTE HEALTH HOSPITAL
# 103617      670098                           RESOLUTE HEALTH HOSPITAL
# 103618      670098                           RESOLUTE HEALTH HOSPITAL
# 103619      670098                           RESOLUTE HEALTH HOSPITAL
# 103620      670103                              MEDICAL CITY ALLIANCE
# 103621      670103                              MEDICAL CITY ALLIANCE
# 103622      670103                              MEDICAL CITY ALLIANCE
# 103623      670106                            PEARLAND MEDICAL CENTER
# 103624      670106                            PEARLAND MEDICAL CENTER
# 103625      670106                            PEARLAND MEDICAL CENTER
# 103626      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 103627      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 103628      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 103629      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 103630      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
# 103631      670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
#
#                            Address           City zipcode County Name  \
# 0           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 1           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 2           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 3           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 4           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 5           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 6           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 7           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 8           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 9           1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 10          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 11          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 12          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 13          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 14          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 15          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 16          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 17          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 18          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 19          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 20          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 21          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 22          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 23          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 24          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 25          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 26          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 27          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 28          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# 29          1108 ROSS CLARK CIRCLE         DOTHAN   36301     HOUSTON
# ...                            ...            ...     ...         ...
# 103602          200 BLOSSOM STREET        WEBSTER   77598      HARRIS
# 103603          200 BLOSSOM STREET        WEBSTER   77598      HARRIS
# 103604          200 BLOSSOM STREET        WEBSTER   77598      HARRIS
# 103605          200 BLOSSOM STREET        WEBSTER   77598      HARRIS
# 103606          200 BLOSSOM STREET        WEBSTER   77598      HARRIS
# 103607          200 BLOSSOM STREET        WEBSTER   77598      HARRIS
# 103608         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103609         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103610         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103611         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103612         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103613         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103614         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103615         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103616         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103617         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103618         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103619         555 CREEKSIDE XING,  NEW BRAUNFELS   78130       COMAL
# 103620  3101 NORTH TARRANT PARKWAY     FORT WORTH   76177     TARRANT
# 103621  3101 NORTH TARRANT PARKWAY     FORT WORTH   76177     TARRANT
# 103622  3101 NORTH TARRANT PARKWAY     FORT WORTH   76177     TARRANT
# 103623  11100 SHADOW CREEK PARKWAY       PEARLAND   77584    BRAZORIA
# 103624  11100 SHADOW CREEK PARKWAY       PEARLAND   77584    BRAZORIA
# 103625  11100 SHADOW CREEK PARKWAY       PEARLAND   77584    BRAZORIA
# 103626            810 W HIGHWAY 71   MARBLE FALLS   78654      BURNET
# 103627            810 W HIGHWAY 71   MARBLE FALLS   78654      BURNET
# 103628            810 W HIGHWAY 71   MARBLE FALLS   78654      BURNET
# 103629            810 W HIGHWAY 71   MARBLE FALLS   78654      BURNET
# 103630            810 W HIGHWAY 71   MARBLE FALLS   78654      BURNET
# 103631            810 W HIGHWAY 71   MARBLE FALLS   78654      BURNET
#
#        Phone Number       Year    Measure ID  \
# 0        3347938701 2011-01-01   MORT_30_AMI
# 1        3347938701 2012-01-01   MORT_30_AMI
# 2        3347938701 2013-01-01   MORT_30_AMI
# 3        3347938701 2014-01-01   MORT_30_AMI
# 4        3347938701 2015-01-01   MORT_30_AMI
# 5        3347938701 2016-01-01   MORT_30_AMI
# 6        3347938701 2014-01-01  MORT_30_CABG
# 7        3347938701 2015-01-01  MORT_30_CABG
# 8        3347938701 2016-01-01  MORT_30_CABG
# 9        3347938701 2011-01-01  MORT_30_COPD
# 10       3347938701 2012-01-01  MORT_30_COPD
# 11       3347938701 2013-01-01  MORT_30_COPD
# 12       3347938701 2014-01-01  MORT_30_COPD
# 13       3347938701 2015-01-01  MORT_30_COPD
# 14       3347938701 2016-01-01  MORT_30_COPD
# 15       3347938701 2011-01-01    MORT_30_HF
# 16       3347938701 2012-01-01    MORT_30_HF
# 17       3347938701 2013-01-01    MORT_30_HF
# 18       3347938701 2014-01-01    MORT_30_HF
# 19       3347938701 2015-01-01    MORT_30_HF
# 20       3347938701 2016-01-01    MORT_30_HF
# 21       3347938701 2011-01-01    MORT_30_PN
# 22       3347938701 2012-01-01    MORT_30_PN
# 23       3347938701 2013-01-01    MORT_30_PN
# 24       3347938701 2014-01-01    MORT_30_PN
# 25       3347938701 2015-01-01    MORT_30_PN
# 26       3347938701 2016-01-01    MORT_30_PN
# 27       3347938701 2011-01-01   MORT_30_STK
# 28       3347938701 2012-01-01   MORT_30_STK
# 29       3347938701 2013-01-01   MORT_30_STK
# ...             ...        ...           ...
# 103602   2815257000 2014-01-01    MORT_30_HF
# 103603   2815257000 2015-01-01    MORT_30_HF
# 103604   2815257000 2016-01-01    MORT_30_HF
# 103605   2815257000 2014-01-01    MORT_30_PN
# 103606   2815257000 2015-01-01    MORT_30_PN
# 103607   2815257000 2016-01-01    MORT_30_PN
# 103608   4698396778 2014-01-01  MORT_30_COPD
# 103609   4698396778 2015-01-01  MORT_30_COPD
# 103610   4698396778 2016-01-01  MORT_30_COPD
# 103611   4698396778 2014-01-01    MORT_30_HF
# 103612   4698396778 2015-01-01    MORT_30_HF
# 103613   4698396778 2016-01-01    MORT_30_HF
# 103614   4698396778 2014-01-01    MORT_30_PN
# 103615   4698396778 2015-01-01    MORT_30_PN
# 103616   4698396778 2016-01-01    MORT_30_PN
# 103617   4698396778 2014-01-01   MORT_30_STK
# 103618   4698396778 2015-01-01   MORT_30_STK
# 103619   4698396778 2016-01-01   MORT_30_STK
# 103620   8176391100 2014-01-01    MORT_30_PN
# 103621   8176391100 2015-01-01    MORT_30_PN
# 103622   8176391100 2016-01-01    MORT_30_PN
# 103623   7137707000 2014-01-01    MORT_30_HF
# 103624   7137707000 2015-01-01    MORT_30_HF
# 103625   7137707000 2016-01-01    MORT_30_HF
# 103626   8302017308 2014-01-01  MORT_30_COPD
# 103627   8302017308 2015-01-01  MORT_30_COPD
# 103628   8302017308 2016-01-01  MORT_30_COPD
# 103629   8302017308 2014-01-01    MORT_30_PN
# 103630   8302017308 2015-01-01    MORT_30_PN
# 103631   8302017308 2016-01-01    MORT_30_PN
#
#                                              Measure Name  Denominator  \
# 0       Acute Myocardial Infarction (AMI) 30-Day Morta...     668.0000
# 1       Acute Myocardial Infarction (AMI) 30-Day Morta...     668.0000
# 2       Acute Myocardial Infarction (AMI) 30-Day Morta...     668.0000
# 3       Acute Myocardial Infarction (AMI) 30-Day Morta...     744.0000
# 4       Acute Myocardial Infarction (AMI) 30-Day Morta...     744.0000
# 5       Acute Myocardial Infarction (AMI) 30-Day Morta...     744.0000
# 6                                     Death rate for CABG     280.0000
# 7                                     Death rate for CABG     280.0000
# 8                                     Death rate for CABG     280.0000
# 9       Death rate for chronic obstructive pulmonary d...     574.0000
# 10      Death rate for chronic obstructive pulmonary d...     574.0000
# 11      Death rate for chronic obstructive pulmonary d...     574.0000
# 12      Death rate for chronic obstructive pulmonary d...     522.0000
# 13      Death rate for chronic obstructive pulmonary d...     522.0000
# 14      Death rate for chronic obstructive pulmonary d...     522.0000
# 15               Heart failure (HF) 30-Day Mortality Rate     746.0000
# 16               Heart failure (HF) 30-Day Mortality Rate     746.0000
# 17               Heart failure (HF) 30-Day Mortality Rate     746.0000
# 18               Heart failure (HF) 30-Day Mortality Rate     858.0000
# 19               Heart failure (HF) 30-Day Mortality Rate     858.0000
# 20               Heart failure (HF) 30-Day Mortality Rate     858.0000
# 21                   Pneumonia (PN) 30-Day Mortality Rate     350.0000
# 22                   Pneumonia (PN) 30-Day Mortality Rate     350.0000
# 23                   Pneumonia (PN) 30-Day Mortality Rate     350.0000
# 24                   Pneumonia (PN) 30-Day Mortality Rate     597.0000
# 25                   Pneumonia (PN) 30-Day Mortality Rate     597.0000
# 26                   Pneumonia (PN) 30-Day Mortality Rate     597.0000
# 27                         Death rate for stroke patients     469.0000
# 28                         Death rate for stroke patients     469.0000
# 29                         Death rate for stroke patients     469.0000
# ...                                                   ...          ...
# 103602           Heart failure (HF) 30-Day Mortality Rate     111.0000
# 103603           Heart failure (HF) 30-Day Mortality Rate     111.0000
# 103604           Heart failure (HF) 30-Day Mortality Rate     111.0000
# 103605               Pneumonia (PN) 30-Day Mortality Rate     114.0000
# 103606               Pneumonia (PN) 30-Day Mortality Rate     114.0000
# 103607               Pneumonia (PN) 30-Day Mortality Rate     114.0000
# 103608  Death rate for chronic obstructive pulmonary d...      71.0000
# 103609  Death rate for chronic obstructive pulmonary d...      71.0000
# 103610  Death rate for chronic obstructive pulmonary d...      71.0000
# 103611           Heart failure (HF) 30-Day Mortality Rate      59.0000
# 103612           Heart failure (HF) 30-Day Mortality Rate      59.0000
# 103613           Heart failure (HF) 30-Day Mortality Rate      59.0000
# 103614               Pneumonia (PN) 30-Day Mortality Rate     109.0000
# 103615               Pneumonia (PN) 30-Day Mortality Rate     109.0000
# 103616               Pneumonia (PN) 30-Day Mortality Rate     109.0000
# 103617                     Death rate for stroke patients      32.0000
# 103618                     Death rate for stroke patients      32.0000
# 103619                     Death rate for stroke patients      32.0000
# 103620               Pneumonia (PN) 30-Day Mortality Rate      26.0000
# 103621               Pneumonia (PN) 30-Day Mortality Rate      26.0000
# 103622               Pneumonia (PN) 30-Day Mortality Rate      26.0000
# 103623           Heart failure (HF) 30-Day Mortality Rate      25.0000
# 103624           Heart failure (HF) 30-Day Mortality Rate      25.0000
# 103625           Heart failure (HF) 30-Day Mortality Rate      25.0000
# 103626  Death rate for chronic obstructive pulmonary d...      26.0000
# 103627  Death rate for chronic obstructive pulmonary d...      26.0000
# 103628  Death rate for chronic obstructive pulmonary d...      26.0000
# 103629               Pneumonia (PN) 30-Day Mortality Rate      60.0000
# 103630               Pneumonia (PN) 30-Day Mortality Rate      60.0000
# 103631               Pneumonia (PN) 30-Day Mortality Rate      60.0000
#
#          Score  Lower Estimate  Higher Estimate  ratio state_fips    state  \
# 0      13.0000         10.9000          15.6000 0.0195          1  Alabama
# 1      13.0000         10.9000          15.6000 0.0195          1  Alabama
# 2      13.0000         10.9000          15.6000 0.0195          1  Alabama
# 3      13.4000         11.4000          15.8000 0.0180          1  Alabama
# 4      13.4000         11.4000          15.8000 0.0180          1  Alabama
# 5      13.4000         11.4000          15.8000 0.0180          1  Alabama
# 6       3.5000          2.1000           5.8000 0.0125          1  Alabama
# 7       3.5000          2.1000           5.8000 0.0125          1  Alabama
# 8       3.5000          2.1000           5.8000 0.0125          1  Alabama
# 9       8.8000          7.0000          11.2000 0.0153          1  Alabama
# 10      8.8000          7.0000          11.2000 0.0153          1  Alabama
# 11      8.8000          7.0000          11.2000 0.0153          1  Alabama
# 12      9.7000          7.6000          12.3000 0.0186          1  Alabama
# 13      9.7000          7.6000          12.3000 0.0186          1  Alabama
# 14      9.7000          7.6000          12.3000 0.0186          1  Alabama
# 15     12.4000         10.5000          14.8000 0.0166          1  Alabama
# 16     12.4000         10.5000          14.8000 0.0166          1  Alabama
# 17     12.4000         10.5000          14.8000 0.0166          1  Alabama
# 18     11.4000          9.5000          13.6000 0.0133          1  Alabama
# 19     11.4000          9.5000          13.6000 0.0133          1  Alabama
# 20     11.4000          9.5000          13.6000 0.0133          1  Alabama
# 21     11.4000          8.9000          14.5000 0.0326          1  Alabama
# 22     11.4000          8.9000          14.5000 0.0326          1  Alabama
# 23     11.4000          8.9000          14.5000 0.0326          1  Alabama
# 24     15.4000         13.0000          18.3000 0.0258          1  Alabama
# 25     15.4000         13.0000          18.3000 0.0258          1  Alabama
# 26     15.4000         13.0000          18.3000 0.0258          1  Alabama
# 27     14.5000         11.8000          17.7000 0.0309          1  Alabama
# 28     14.5000         11.8000          17.7000 0.0309          1  Alabama
# 29     14.5000         11.8000          17.7000 0.0309          1  Alabama
# ...        ...             ...              ...    ...        ...      ...
# 103602 11.2000          8.1000          15.1000 0.1009         48    Texas
# 103603 11.2000          8.1000          15.1000 0.1009         48    Texas
# 103604 11.2000          8.1000          15.1000 0.1009         48    Texas
# 103605 13.4000         10.4000          17.3000 0.1175         48    Texas
# 103606 13.4000         10.4000          17.3000 0.1175         48    Texas
# 103607 13.4000         10.4000          17.3000 0.1175         48    Texas
# 103608  9.5000          6.6000          13.3000 0.1338         48    Texas
# 103609  9.5000          6.6000          13.3000 0.1338         48    Texas
# 103610  9.5000          6.6000          13.3000 0.1338         48    Texas
# 103611 11.7000          8.2000          16.4000 0.1983         48    Texas
# 103612 11.7000          8.2000          16.4000 0.1983         48    Texas
# 103613 11.7000          8.2000          16.4000 0.1983         48    Texas
# 103614 15.3000         11.9000          19.6000 0.1404         48    Texas
# 103615 15.3000         11.9000          19.6000 0.1404         48    Texas
# 103616 15.3000         11.9000          19.6000 0.1404         48    Texas
# 103617 13.2000          9.3000          18.6000 0.4125         48    Texas
# 103618 13.2000          9.3000          18.6000 0.4125         48    Texas
# 103619 13.2000          9.3000          18.6000 0.4125         48    Texas
# 103620 14.6000         10.1000          20.9000 0.5615         48    Texas
# 103621 14.6000         10.1000          20.9000 0.5615         48    Texas
# 103622 14.6000         10.1000          20.9000 0.5615         48    Texas
# 103623 11.5000          7.7000          16.5000 0.4600         48    Texas
# 103624 11.5000          7.7000          16.5000 0.4600         48    Texas
# 103625 11.5000          7.7000          16.5000 0.4600         48    Texas
# 103626  8.0000          5.3000          11.9000 0.3077         48    Texas
# 103627  8.0000          5.3000          11.9000 0.3077         48    Texas
# 103628  8.0000          5.3000          11.9000 0.3077         48    Texas
# 103629 14.8000         10.9000          19.9000 0.2467         48    Texas
# 103630 14.8000         10.9000          19.9000 0.2467         48    Texas
# 103631 14.8000         10.9000          19.9000 0.2467         48    Texas
#
#        state_abbr    county          city
# 0              AL   Houston        Taylor
# 1              AL   Houston        Taylor
# 2              AL   Houston        Taylor
# 3              AL   Houston        Taylor
# 4              AL   Houston        Taylor
# 5              AL   Houston        Taylor
# 6              AL   Houston        Taylor
# 7              AL   Houston        Taylor
# 8              AL   Houston        Taylor
# 9              AL   Houston        Taylor
# 10             AL   Houston        Taylor
# 11             AL   Houston        Taylor
# 12             AL   Houston        Taylor
# 13             AL   Houston        Taylor
# 14             AL   Houston        Taylor
# 15             AL   Houston        Taylor
# 16             AL   Houston        Taylor
# 17             AL   Houston        Taylor
# 18             AL   Houston        Taylor
# 19             AL   Houston        Taylor
# 20             AL   Houston        Taylor
# 21             AL   Houston        Taylor
# 22             AL   Houston        Taylor
# 23             AL   Houston        Taylor
# 24             AL   Houston        Taylor
# 25             AL   Houston        Taylor
# 26             AL   Houston        Taylor
# 27             AL   Houston        Taylor
# 28             AL   Houston        Taylor
# 29             AL   Houston        Taylor
# ...           ...       ...           ...
# 103602         TX    Harris       Webster
# 103603         TX    Harris       Webster
# 103604         TX    Harris       Webster
# 103605         TX    Harris       Webster
# 103606         TX    Harris       Webster
# 103607         TX    Harris       Webster
# 103608         TX     Comal   Canyon lake
# 103609         TX     Comal   Canyon lake
# 103610         TX     Comal   Canyon lake
# 103611         TX     Comal   Canyon lake
# 103612         TX     Comal   Canyon lake
# 103613         TX     Comal   Canyon lake
# 103614         TX     Comal   Canyon lake
# 103615         TX     Comal   Canyon lake
# 103616         TX     Comal   Canyon lake
# 103617         TX     Comal   Canyon lake
# 103618         TX     Comal   Canyon lake
# 103619         TX     Comal   Canyon lake
# 103620         TX   Tarrant    Fort worth
# 103621         TX   Tarrant    Fort worth
# 103622         TX   Tarrant    Fort worth
# 103623         TX  Brazoria      Pearland
# 103624         TX  Brazoria      Pearland
# 103625         TX  Brazoria      Pearland
# 103626         TX    Burnet  Cypress mill
# 103627         TX    Burnet  Cypress mill
# 103628         TX    Burnet  Cypress mill
# 103629         TX    Burnet  Cypress mill
# 103630         TX    Burnet  Cypress mill
# 103631         TX    Burnet  Cypress mill
#
# [103632 rows x 20 columns]

# %% [markdown]
# # Create an overview of the complications per U.S. state

# %% [markdown]
# * Return a sorted list with the overall complication rate per state.
# * Ignore that the data is for multiple years.
# * Focus on the **best** ten states.

# %%
# set up an empty list and groupby merged dataframe into states, after sorting in descending roll based on ratio's mean value, return it back to list
L=[]
L.append(M.groupby(by='state')['ratio'].mean().sort_values(ascending=False))
L

# best ten should have the smallest 10 ratio
best_ten=M.groupby(by='state')['ratio'].mean().nsmallest(10)
best_ten
# Out:
# [state
#  South dakota           0.2311
#  Wyoming                0.2226
#  Montana                0.2167
#  North dakota           0.2114
#  Minnesota              0.2064
#  Alaska                 0.2039
#  Nebraska               0.1982
#  Utah                   0.1891
#  Kansas                 0.1847
#  Iowa                   0.1829
#  Idaho                  0.1808
#  Oregon                 0.1805
#  Colorado               0.1795
#  Wisconsin              0.1748
#  New mexico             0.1717
#  Oklahoma               0.1618
#  Mississippi            0.1566
#  Hawaii                 0.1561
#  Arkansas               0.1503
#  Washington             0.1443
#  West virginia          0.1428
#  Alabama                0.1333
#  Louisiana              0.1332
#  Kentucky               0.1281
#  Georgia                0.1267
#  Indiana                0.1259
#  Tennessee              0.1244
#  Nevada                 0.1223
#  Texas                  0.1212
#  California             0.1211
#  Missouri               0.1144
#  North carolina         0.1116
#  Ohio                   0.1098
#  Michigan               0.1093
#  Arizona                0.1084
#  Illinois               0.1083
#  Pennsylvania           0.1060
#  South carolina         0.1051
#  New york               0.1038
#  Virginia               0.0904
#  District of columbia   0.0883
#  Florida                0.0806
#  Maryland               0.0705
#  Delaware               0.0510
#  Name: ratio, dtype: float64]
# state
# Delaware               0.0510
# Maryland               0.0705
# Florida                0.0806
# District of columbia   0.0883
# Virginia               0.0904
# New york               0.1038
# South carolina         0.1051
# Pennsylvania           0.1060
# Illinois               0.1083
# Arizona                0.1084
# Name: ratio, dtype: float64

# %% [markdown]
# # Create an overview of the change in complications across U.S. states

# %% [markdown]
# * Focus on the deadly complications only.
# * Calculate the change as follows: **(average rate for last year in dataset - average rate for first year in dataset)/(average rate for first year in dataset)**

# %%
# Get values of each year's average rate on deadly complication
C=M.groupby(['state', 'Year'])['ratio'].size()


# Calculate based on equation
#C[C['Year']=='2016-01-01']
change=(C['Year'=='2016-01-01']-C['Year'=='2011-01-01'])/C['Year'=='2011-01-01']
change
#C['Year']['2016-01-01']
#change
# Out:
# 0.0

# %% [markdown]
# Which state has improved the most?

# %% [markdown]
# Which state has the worst development?

# %% [markdown]
# # Bonus

# %% [markdown]
# Which state has the worst development for 'Deaths among Patients with Serious Treatable Complications after Surgery'?
